# %%
import os
import re
import requests
import base64
from typing import Dict, List, Optional, Any
from google import genai
from google.genai import types
import json
import logging

# Initialize Gemini client globally
gemini_client = None
github_session = None
github_headers = {}

def initialize_clients(gemini_api_key: str, github_token: Optional[str] = None):
    """Initialize the clients for GitHub API and Gemini."""
    global gemini_client, github_session, github_headers
    
    gemini_client = genai.Client(api_key=gemini_api_key)
    github_session = requests.Session()
    
    # Set up headers for GitHub API
    github_headers = {
        'Accept': 'application/vnd.github.v3+json',
        'User-Agent': 'GitHub-Architecture-Analyzer'
    }
    if github_token:
        github_headers['Authorization'] = f'token {github_token}'

initialize_clients("AIzaSyCADVfX-Zt3EG-W3aD2mSxqyXD0jBEPkVM")

# %%
def validate_repository(github_url: str) -> Optional[Dict[str, str]]:
    """Validate and extract repository information from GitHub URL."""
    try:
        # Extract owner and repo name from URL
        pattern = r'github\.com/([^/]+)/([^/]+?)(?:\.git)?/?$'
        match = re.search(pattern, github_url)
        
        if not match:
            return None
        
        owner, repo_name = match.groups()
        
        # Fetch repository info via GitHub API
        api_url = f"https://api.github.com/repos/{owner}/{repo_name}"
        response = github_session.get(api_url, headers=github_headers)
        
        if response.status_code != 200:
            logging.error(f"GitHub API error: {response.status_code}")
            return None
        
        repo_data = response.json()
        
        return {
            'owner': owner,
            'name': repo_name,
            'full_name': repo_data.get('full_name', f"{owner}/{repo_name}"),
            'description': repo_data.get('description', ''),
            'language': repo_data.get('language', 'Unknown'),
            'stars': repo_data.get('stargazers_count', 0),
            'forks': repo_data.get('forks_count', 0),
            'url': github_url
        }
        
    except Exception as e:
        logging.error(f"Error validating repository: {e}")
        return None

# %%
githubval = validate_repository("https://github.com/tushararora-dev/Architecture_Documentation_Generator")
print(githubval)
# Out:
# {'owner': 'tushararora-dev', 'name': 'Architecture_Documentation_Generator', 'full_name': 'tushararora-dev/Architecture_Documentation_Generator', 'description': "This is a GitHub Architecture Documentation Generator built with Streamlit that analyzes GitHub repositories and generates comprehensive architecture documentation using AI. The application leverages Google's Gemini AI API to analyze repository code and structure, then automatically generates professional documentation in PDF and DOCX formats.", 'language': 'Python', 'stars': 0, 'forks': 0, 'url': 'https://github.com/tushararora-dev/Architecture_Documentation_Generator'}

# %%
# Supported file extensions for analysis
CODE_EXTENSIONS = {
    '.py', '.js', '.ts', '.jsx', '.tsx', '.java', '.cpp', '.c', '.h',
    '.cs', '.php', '.rb', '.go', '.rs', '.swift', '.kt', '.scala',
    '.html', '.css', '.scss', '.sass', '.less', '.vue', '.svelte',
    '.json', '.xml', '.yaml', '.yml', '.toml', '.ini', '.cfg', '.md',
    '.txt', '.dockerfile', '.makefile', '.gradle', '.properties'
}

# Files and directories to prioritize for analysis
PRIORITY_FILES = {
    'package.json', 'requirements.txt', 'cargo.toml', 'pom.xml',
    'build.gradle', 'gemfile', 'composer.json', 'setup.py',
    'readme.md', 'architecture.md', 'design.md', 'contributing.md',
    'dockerfile', 'makefile', 'changelog.md', 'license'
}

# Directories and files to skip (not important for architecture)
SKIP_PATTERNS = {
    'test', 'tests', '__tests__', 'spec', 'specs', '__pycache__',
    'node_modules', '.git', '.github', 'dist', 'build', 'target',
    'coverage', '.coverage', '.pytest_cache', '.tox', 'venv', 'env',
    '.env', 'logs', 'tmp', 'temp', '.DS_Store', '.vscode', '.idea',
    'vendor', 'public/assets', 'static/assets', 'assets/images'
}


def fetch_repository_contents(owner: str, repo_name: str, path: str = "") -> List[Dict]:
    """Fetch repository contents for a specific path."""
    try:
        api_url = f"https://api.github.com/repos/{owner}/{repo_name}/contents/{path}"
        response = github_session.get(api_url, headers=github_headers)
        
        if response.status_code != 200:
            logging.warning(f"Could not fetch contents for path {path}: {response.status_code}")
            return []
        
        contents = response.json()
        if not isinstance(contents, list):
            contents = [contents]
        
        return contents
        
    except Exception as e:
        logging.warning(f"Error fetching contents for path {path}: {e}")
        return []
    
def should_skip_path(path: str) -> bool:
    """Check if a path should be skipped based on skip patterns."""
    path_lower = path.lower()
    
    # Skip if any part of the path matches skip patterns
    for skip_pattern in SKIP_PATTERNS:
        if skip_pattern in path_lower:
            return True
    
    # Skip common non-code files
    if path_lower.endswith(('.png', '.jpg', '.jpeg', '.gif', '.svg', '.ico',
                           '.pdf', '.zip', '.tar', '.gz', '.exe', '.dmg',
                           '.app', '.deb', '.rpm', '.msi')):
        return True
    
    return False

def get_file_type(filename: str) -> str:
    """Determine file type based on extension."""
    ext = os.path.splitext(filename)[1].lower()
    
    type_mapping = {
        '.py': 'Python',
        '.js': 'JavaScript',
        '.ts': 'TypeScript',
        '.jsx': 'React JSX',
        '.tsx': 'React TSX',
        '.java': 'Java',
        '.cpp': 'C++',
        '.c': 'C',
        '.h': 'Header',
        '.cs': 'C#',
        '.php': 'PHP',
        '.rb': 'Ruby',
        '.go': 'Go',
        '.rs': 'Rust',
        '.swift': 'Swift',
        '.kt': 'Kotlin',
        '.html': 'HTML',
        '.css': 'CSS',
        '.scss': 'SCSS',
        '.json': 'JSON',
        '.md': 'Markdown',
        '.yaml': 'YAML',
        '.yml': 'YAML',
        '.dockerfile': 'Docker',
        '.makefile': 'Makefile'
    }
    
    return type_mapping.get(ext, 'Other')

def fetch_all_repository_files(github_url: str) -> Dict[str, Any]:
    """Fetch all relevant repository files and structure."""
    try:
        # Extract owner and repo name
        pattern = r'github\.com/([^/]+)/([^/]+?)(?:\.git)?/?$'
        match = re.search(pattern, github_url)
        if not match:
            raise ValueError("Invalid GitHub URL")
            
        owner, repo_name = match.groups()
        
        # Initialize structure
        structure = {
            'files': [],
            'directories': [],
            'key_files': {},
            'statistics': {
                'total_files': 0,
                'code_files': 0,
                'analyzed_files': 0,
                'skipped_files': 0,
                'languages': {}
            }
        }
        
        # Queue for breadth-first traversal
        paths_to_process = [""]
        processed_paths = set()
        
        while paths_to_process:
            current_path = paths_to_process.pop(0)
            
            if current_path in processed_paths:
                continue
            processed_paths.add(current_path)
            
            # Skip if path matches skip patterns
            if current_path and should_skip_path(current_path):
                structure['statistics']['skipped_files'] += 1
                continue
            
            contents = fetch_repository_contents(owner, repo_name, current_path)
            
            for content in contents:
                content_path = content['path']
                
                # Skip if matches skip patterns
                if should_skip_path(content_path):
                    structure['statistics']['skipped_files'] += 1
                    continue
                
                if content['type'] == "dir":
                    structure['directories'].append(content_path)
                    # Add directory to processing queue
                    paths_to_process.append(content_path)
                    
                elif content['type'] == "file":
                    file_info = {
                        'path': content_path,
                        'name': content['name'],
                        'size': content['size'],
                        'type': get_file_type(content['name'])
                    }
                    
                    structure['files'].append(file_info)
                    structure['statistics']['total_files'] += 1
                    
                    # Count file by extension
                    ext = os.path.splitext(content['name'])[1].lower()
                    if ext in CODE_EXTENSIONS:
                        structure['statistics']['code_files'] += 1
                        structure['statistics']['languages'][ext] = structure['statistics']['languages'].get(ext, 0) + 1
                    
                    # Fetch content for relevant files
                    should_analyze = (
                        content['name'].lower() in [f.lower() for f in PRIORITY_FILES] or
                        ext in CODE_EXTENSIONS or
                        content['size'] < 100000  # Files under 100KB
                    )
                    
                    if should_analyze:
                        try:
                            # Get file content
                            file_response = github_session.get(content['download_url'])
                            if file_response.status_code == 200:
                                file_content = file_response.text
                                structure['key_files'][content_path] = {
                                    'content': file_content,
                                    'size': content['size'],
                                    'type': ext
                                }
                                structure['statistics']['analyzed_files'] += 1
                        except Exception as e:
                            logging.warning(f"Could not fetch file {content_path}: {e}")
        
        return structure
        
    except Exception as e:
        logging.error(f"Error fetching repository structure: {e}")
        raise

# %%
fetch = fetch_all_repository_files("https://github.com/tushararora-dev/Architecture_Documentation_Generator")
print(fetch)
# Out:
# {'files': [{'path': 'app.py', 'name': 'app.py', 'size': 10368, 'type': 'Python'}, {'path': 'document_generator_functions.py', 'name': 'document_generator_functions.py', 'size': 10763, 'type': 'Python'}, {'path': 'github_analyzer_functions.py', 'name': 'github_analyzer_functions.py', 'size': 16380, 'type': 'Python'}, {'path': 'readme.md', 'name': 'readme.md', 'size': 3895, 'type': 'Markdown'}, {'path': 'requirements.txt', 'name': 'requirements.txt', 'size': 124, 'type': 'Other'}, {'path': 'utils.py', 'name': 'utils.py', 'size': 5622, 'type': 'Python'}, {'path': '.streamlit/config.toml', 'name': 'config.toml', 'size': 288, 'type': 'Other'}], 'directories': ['.streamlit'], 'key_files': {'app.py': {'content': 'import streamlit as st\nimport os\nimport tempfile\nimport github_analyzer_functions as github_funcs\nimport document_generator_functions as doc_funcs\nimport base64\n\ndef main():\n    st.set_page_config(\n        page_title="GitHub Architecture Documentation Generator",\n        page_icon="📚",\n        layout="wide"\n    )\n    \n    st.title("📚 GitHub Architecture Documentation Generator")\n    st.markdown("Generate comprehensive architecture documentation from GitHub repositories using AI")\n    \n    # Sidebar for configuration\n    with st.sidebar:\n        st.header("Configuration")\n        \n        # API Key configuration\n        gemini_api_key = st.text_input(\n            "Gemini API Key",\n            value=os.getenv("GEMINI_API_KEY"),\n            type="password",\n            help="Enter your Gemini API key"\n        )\n        \n        github_token = st.text_input(\n            "GitHub Token (Optional)",\n            value=os.getenv("GITHUB_TOKEN", ""),\n            type="password",\n            help="GitHub personal access token for higher rate limits"\n        )\n        \n        st.markdown("---")\n        st.markdown("### About")\n        st.markdown("""\n        This tool analyzes GitHub repositories and generates comprehensive architecture documentation including:\n        - High-level architecture overview\n        - Module/component breakdown\n        - Data flow descriptions\n        - Design patterns identification\n        - Mermaid diagrams\n        """)\n    \n    # Main content area\n    col1, col2 = st.columns([2, 1])\n    \n    with col1:\n        st.header("Repository Analysis")\n        \n        # GitHub URL input\n        github_url = st.text_input(\n            "GitHub Repository URL",\n            placeholder="https://github.com/slab/quill",\n            help="Enter the full GitHub repository URL"\n        )\n        \n        # Analysis options\n        st.subheader("Analysis Options")\n        col_opt1, col_opt2 = st.columns(2)\n        \n        with col_opt1:\n            include_diagrams = st.checkbox("Include Mermaid Diagrams", value=True)\n            include_patterns = st.checkbox("Analyze Design Patterns", value=True)\n        \n        with col_opt2:\n            include_dependencies = st.checkbox("Analyze Dependencies", value=True)\n            include_data_flow = st.checkbox("Include Data Flow Analysis", value=True)\n        \n        st.info("📁 This tool will analyze ALL relevant files in the repository while automatically skipping test files, build artifacts, and other non-essential files.")\n        \n        # Analyze button\n        if st.button("🔍 Analyze Repository"):\n            if not github_url:\n                st.error("Please enter a GitHub repository URL")\n                return\n            \n            if not gemini_api_key:\n                st.error("Please provide a Gemini API key")\n                return\n            \n            try:\n                # Initialize clients\n                github_funcs.initialize_clients(gemini_api_key, github_token if github_token else None)\n                \n                # Progress tracking\n                progress_bar = st.progress(0)\n                status_text = st.empty()\n                \n               ...

# %%
from pprint import pprint
pprint(fetch)
# Out:
# {'directories': ['.streamlit'],
#  'files': [{'name': 'app.py',
#             'path': 'app.py',
#             'size': 10368,
#             'type': 'Python'},
#            {'name': 'document_generator_functions.py',
#             'path': 'document_generator_functions.py',
#             'size': 10763,
#             'type': 'Python'},
#            {'name': 'github_analyzer_functions.py',
#             'path': 'github_analyzer_functions.py',
#             'size': 16380,
#             'type': 'Python'},
#            {'name': 'readme.md',
#             'path': 'readme.md',
#             'size': 3895,
#             'type': 'Markdown'},
#            {'name': 'requirements.txt',
#             'path': 'requirements.txt',
#             'size': 124,
#             'type': 'Other'},
#            {'name': 'utils.py',
#             'path': 'utils.py',
#             'size': 5622,
#             'type': 'Python'},
#            {'name': 'config.toml',
#             'path': '.streamlit/config.toml',
#             'size': 288,
#             'type': 'Other'}],
#  'key_files': {'.streamlit/config.toml': {'content': '[server]\n'
#                                                      'headless = true\n'
#                                                      'address = "0.0.0.0"\n'
#                                                      'port = 5000\n'
#                                                      '\n'
#                                                      '[theme]\n'
#                                                      'primaryColor = '
#                                                      '"#ff0000ff"             '
#                                                      '# Vibrant purple\n'
#                                                      'backgroundColor = '
#                                                      '"#0D0B1A"          # '
#                                                      'Very dark purple-tinted '
#                                                      'black\n'
#                                                      'secondaryBackgroundColor '
#                                                      '= "#1A1628" # Dark '
#                                                      'violet grey\n'
#                                                      'textColor = "#FFFFFF"\n'
#                                                      'font = "sans serif"',
#                                           'size': 288,
#                                           'type': '.toml'},
#                'app.py': {'content': 'import streamlit as st\n'
#                                      'import os\n'
#                                      'import tempfile\n'
#                                      'import github_analyzer_functions as '
#                                      'github_funcs\n'
#                                      'import document_generator_functions as '
#                                      'doc_funcs\n'
#                                      'import base64\n'
#                                      '\n'
#                                      'def main():\n'
#                                      '    st.set_page_config(\n'
#                                      '        page_title="GitHub Architecture '
#                                      'Documentation Generator",\n'
#                                      '        page_icon="📚",\n'
#                                      '        layout="wide"\n'
#                                      '    )\n'
#                                      '    \n'
#                                      '    st.title("📚 GitHub Architecture '
#                                      'Documentation Generator")\n'
#                                      '    st.markdown("Generate comprehensive '
#                                      'architecture documentation from GitHub '
#                                      'repositories using AI")\n'
#                                      '    \n'
#                                      '    # Sidebar for configuration\n'
#                                      '    with st.sidebar:\n'
#                                      '        st.header("Configuration")\n'
#                                      '        \n'
#                                      '        # API Key configuration\n'
#                                      '        gemini_api_key = st.text_input(\n'
#                                      '            "Gemini API Key",\n'
#                                      '            '
#                                      'value=os.getenv("GEMINI_API_KEY"),\n'
#                                      '            type="password",\n'
#                                      '            help="Enter your Gemini API '
#                                      'key"\n'
#                                      '        )\n'
#                                      '        \n'
#                                      '        github_token = st.text_input(\n'
#                                      '            "GitHub Token (Optional)",\n'
#                                      '            '
#                                      'value=os.getenv("GITHUB_TOKEN", ""),\n'
#                                      '            type="password",\n'
#                                      '            help="GitHub personal access '
#                                      'token for higher rate limits"\n'
#                                      '        )\n'
#                                      '        \n'
#                                      '        st.markdown("---")\n'
#                                      '        st.markdown("### About")\n'
#                                      '        st.markdown("""\n'
#                                      '        This tool analyzes GitHub '
#                                      'repositories and generates comprehensive '
#                                      'architecture documentation including:\n'
#                                      '        - High-level architecture '
#                                      'overview\n'
#                                      '        - Module/component breakdown\n'
#                                      '        - Data flow descriptions\n'
#                                      '        - Design patterns '
#                                      'identification\n'
#                                      '        - Mermaid diagrams\n'
#                                      '        """)\n'
#                                      '    \n'
#                                      '    # Main content area\n'
#                                      '    col1, col2 = st.columns([2, 1])\n'
#                                      '    \n'
#                                      '    with col1:\n'
#                                      '        st.header("Repository '
#                                      'Analysis")\n'
#                                      '        \n'
#                                      '        # GitHub URL input\n'
#                                      '        github_url = st.text_input(\n'
#                                      '            "GitHub Repository URL",\n'
#                                      '            '
#                                      'placeholder="https://github.com/slab/quill",\n'
#                                      '            help="Enter the full GitHub '
#                                      'repository URL"\n'
#                                      '        )\n'
#                                      '        \n'
#                                      '        # Analysis options\n'
#                                      '        st.subheader("Analysis '
#                                      'Options")\n'
#                                      '        col_opt1, col_opt2 = '
#                                      'st.columns(2)\n'
#                                      '        \n'
#                                      '        with col_opt1:\n'
#                                      '            include_diagrams = '
#                                      'st.checkbox("Include Mermaid Diagrams", '
#                                      'value=True)\n'
#                                      '            include_patterns = '
#                                      'st.checkbox("Analyze Design Patterns", '
#                                      'value=True)\n'
#                                      '        \n'
#                                      '        with col_opt2:\n'
#                                      '            include_dependencies = '
#                                      'st.checkbox("Analyze Dependencies", '
#                                      'value=True)\n'
#                                      '            include_data_flow = '
#                                      'st.checkbox("Include Data Flow '
#                                      'Analysis", value=True)\n'
#                                      '        \n'
#                                      '        st.info("📁 This tool will '
#                                      'analyze ALL relevant files in the '
#                                      'repository while automatically skipping '
#                                      'test files, build artifacts, and other '
#                                      'non-essential files.")\n'
#                                      '        \n'
#                                      '        # Analyze button\n'
#                                      '        if st.button("🔍 Analyze '
#                                      'Repository"):\n'
#                                      '            if not github_url:\n'
#                                      '                st.error("Please enter a '
#                                      'GitHub repository URL")\n'
#                                      '                return\n'
#                                      '            \n'
#                                      '            if not gemini_api_key:\n'
#                                      '                st.error("Please provide '
#                                      'a Gemini API key")\n'
#                                      '                return\n'
#                                      '            \n'
#                                      '            try:\n'
#                                      '                # Initialize clients\n'
#                                      '                '
#                                      'github_funcs.initialize_clients(gemini_api_key, '
#                                      'github_token if github_token else None)\n'
#                                      '                \n'
#                                      '                # Progress tracking\n'
#                                      '                progress_bar = '
#                                      'st.progress(0)\n'
#                                      '                status_text = '
#                                      'st.empty()\n'
#                                      '                \n'
#                                      '                # Step 1: Validate and '
#                                      'fetch repository\n'
#                                      '                '
#                                      'status_text.text("Validating '
#                                      'repository...")\n'
#                                      '                '
#                                      'progress_bar.progress(10)\n'
#                                      '                \n'
#                                      '                repo_info = '
#                                      'github_funcs.validate_repository(github_url)\n'
#                                      '                if not repo_info:\n'
#                                      '                    st.error("Invalid '
#                                      'repository URL or repository not '
#                                      'accessible")\n'
#                                      '                    return\n'
#                                      '                \n'
#                                      '                st.success(f"Repository '
#                                      "found: {repo_info['name']} by "
#                                      '{repo_info[\'owner\']}")\n'
#                                      '                \n'
#                                      '                # Step 2: Fetch ALL '
#                                      'repository files (not limited)\n'
#                                      '                '
#                                      'status_text.text("Fetching all '
#                                      'repository files...")\n'
#                                      '                '
#                                      'progress_bar.progress(30)\n'
#                                      '                \n'
#                                      '                repo_structure = '
#                                      'github_funcs.fetch_all_repository_files(github_url)\n'
#                                      '                \n'
#                                      '                # Show progress info\n'
#                                      '                stats = '
#                                      "repo_structure['statistics']\n"
#                                      '                st.info(f"Found '
#                                      "{stats['total_files']} total files, "
#                                      "analyzing {stats['analyzed_files']} "
#                                      'relevant files (skipped '
#                                      "{stats['skipped_files']} test/build "
#                                      'files)")\n'
#                                      '                \n'
#                                      '                # Step 3: Analyze with '
#                                      'Gemini\n'
#                                      '                '
#                                      'status_text.text("Analyzing repository '
#                                      'with AI...")\n'
#                                      '                '
#                                      'progress_bar.progress(60)\n'
#                                      '                \n'
#                                      '                analysis_options = {\n'
#                                      "                    'include_diagrams': "
#                                      'include_diagrams,\n'
#                                      "                    'include_patterns': "
#                                      'include_patterns,\n'
#                                      '                    '
#                                      "'include_dependencies': "
#                                      'include_dependencies,\n'
#                                      "                    'include_data_flow': "
#                                      'include_data_flow\n'
#                                      '                }\n'
#                                      '                \n'
#                                      '                documentation = '
#                                      'github_funcs.analyze_repository_with_ai(repo_structure, '
#                                      'analysis_options)\n'
#                                      '                \n'
#                                      '                # Step 4: Prepare for '
#                                      'document generation\n'
#                                      '                '
#                                      'status_text.text("Preparing '
#                                      'documentation...")\n'
#                                      '                '
#                                      'progress_bar.progress(90)\n'
#                                      '                \n'
#                                      '                # Store results in '
#                                      'session state\n'
#                                      '                '
#                                      'st.session_state.documentation = '
#                                      'documentation\n'
#                                      '                '
#                                      'st.session_state.repo_info = repo_info\n'
#                                      '                \n'
#                                      '                '
#                                      'progress_bar.progress(100)\n'
#                                      '                '
#                                      'status_text.text("Analysis complete!")\n'
#                                      '                \n'
#                                      '                st.success("✅ '
#                                      'Documentation generated successfully!")\n'
#                                      '                \n'
#                                      '            except Exception as e:\n'
#                                      '                st.error(f"Error during '
#                                      'analysis: {str(e)}")\n'
#                                      '                st.exception(e)\n'
#                                      '    \n'
#                                      '    with col2:\n'
#                                      '\n'
#                                      '\n'
#                                      '        st.subheader("💡 Quick '
#                                      'Examples")        \n'
#                                      '        example_repos = [\n'
#                                      '            {\n'
#                                      '                "name": "Quill Editor",\n'
#                                      '                "url": '
#                                      '"https://github.com/slab/quill",\n'
#                                      '                "description": "Modern '
#                                      'WYSIWYG editor"\n'
#                                      '            }\n'
#                                      '        ]\n'
#                                      '\n'
#                                      '        for repo in example_repos:\n'
#                                      '            if st.button(f"📁 '
#                                      '{repo[\'name\']}", key=repo[\'url\']):\n'
#                                      '                st.text((f"📄 '
#                                      '{repo[\'url\']}"))\n'
#                                      '    \n'
#                                      '    # Display results if available\n'
#                                      '    if hasattr(st.session_state, '
#                                      "'documentation') and "
#                                      'st.session_state.documentation:\n'
#                                      '        st.markdown("---")\n'
#                                      '        st.header("📋 Generated '
#                                      'Documentation")\n'
#                                      '        \n'
#                                      '        # Create tabs for different '
#                                      'sections\n'
#                                      '        tabs = st.tabs([\n'
#                                      '            "Overview", \n'
#                                      '            "Architecture", \n'
#                                      '            "Modules", \n'
#                                      '            "Data Flow", \n'
#                                      '            "Design Patterns",\n'
#                                      '            "Export"\n'
#                                      '        ])\n'
#                                      '        \n'
#                                      '        doc = '
#                                      'st.session_state.documentation\n'
#                                      '        \n'
#                                      '        with tabs[0]:  # Overview\n'
#                                      '            st.subheader("Repository '
#                                      'Overview")\n'
#                                      '            '
#                                      "st.markdown(doc.get('overview', 'No "
#                                      "overview available'))\n"
#                                      '            \n'
#                                      "            if 'key_statistics' in doc:\n"
#                                      '                col1, col2, col3, col4, '
#                                      'col5 = st.columns(5)\n'
#                                      '                stats = '
#                                      "doc['key_statistics']\n"
#                                      '                col1.metric("Total '
#                                      'Files", stats.get(\'total_files\', '
#                                      "'N/A'))\n"
#                                      '                col2.metric("Code '
#                                      'Files", stats.get(\'code_files\', '
#                                      "'N/A'))\n"
#                                      '                col3.metric("Analyzed '
#                                      'Files", stats.get(\'analyzed_files\', '
#                                      "'N/A'))\n"
#                                      '                col4.metric("Main '
#                                      'Language", stats.get(\'main_language\', '
#                                      "'N/A'))\n"
#                                      '                col5.metric("Modules '
#                                      'Found", stats.get(\'modules_count\', '
#                                      "'N/A'))\n"
#                                      '        \n'
#                                      '        with tabs[1]:  # Architecture\n'
#                                      '            st.subheader("High-Level '
#                                      'Architecture")\n'
#                                      '            '
#                                      "st.markdown(doc.get('architecture', 'No "
#                                      "architecture description available'))\n"
#                                      '            \n'
#                                      "            if 'architecture_diagram' in "
#                                      'doc:\n'
#                                      '                '
#                                      'st.subheader("Architecture Diagram")\n'
#                                      '                '
#                                      "st.code(doc['architecture_diagram'], "
#                                      "language='mermaid')\n"
#                                      '        \n'
#                                      '        with tabs[2]:  # Modules\n'
#                                      '            st.subheader("Module '
#                                      'Breakdown")\n'
#                                      '            \n'
#                                      "            if 'modules_table' in doc:\n"
#                                      '                '
#                                      "st.dataframe(doc['modules_table'], "
#                                      'use_container_width=True)\n'
#                                      '            else:\n'
#                                      '                '
#                                      "st.markdown(doc.get('modules', 'No "
#                                      "module information available'))\n"
#                                      '        \n'
#                                      '        with tabs[3]:  # Data Flow\n'
#                                      '            st.subheader("Data Flow '
#                                      'Analysis")\n'
#                                      '            '
#                                      "st.markdown(doc.get('data_flow', 'No "
#                                      "data flow analysis available'))\n"
#                                      '            \n'
#                                      "            if 'data_flow_diagram' in "
#                                      'doc:\n'
#                                      '                st.subheader("Data Flow '
#                                      'Diagram")\n'
#                                      '                '
#                                      "st.code(doc['data_flow_diagram'], "
#                                      "language='mermaid')\n"
#                                      '        \n'
#                                      '        with tabs[4]:  # Design '
#                                      'Patterns\n'
#                                      '            st.subheader("Design '
#                                      'Patterns")\n'
#                                      '            '
#                                      "st.markdown(doc.get('design_patterns', "
#                                      "'No design patterns analysis "
#                                      "available'))\n"
#                                      '        \n'
#                                      '        with tabs[5]:  # Export\n'
#                                      '            st.subheader("Export '
#                                      'Documentation")\n'
#                                      '            \n'
#                                      '            col1, col2 = st.columns(2)\n'
#                                      '            \n'
#                                      '            with col1:\n'
#                                      '                if st.button("📄 Download '
#                                      'as PDF"):\n'
#                                      '                    try:\n'
#                                      '                        pdf_buffer = '
#                                      'doc_funcs.generate_pdf_document(\n'
#                                      '                            '
#                                      'st.session_state.documentation,\n'
#                                      '                            '
#                                      'st.session_state.repo_info\n'
#                                      '                        )\n'
#                                      '                        \n'
#                                      '                        '
#                                      'st.download_button(\n'
#                                      '                            label="💾 '
#                                      'Download PDF",\n'
#                                      '                            '
#                                      'data=pdf_buffer.getvalue(),\n'
#                                      '                            '
#                                      'file_name=f"{st.session_state.repo_info[\'name\']}_architecture.pdf",\n'
#                                      '                            '
#                                      'mime="application/pdf"\n'
#                                      '                        )\n'
#                                      '                        \n'
#                                      '                    except Exception as '
#                                      'e:\n'
#                                      '                        st.error(f"Error '
#                                      'generating PDF: {str(e)}")\n'
#                                      '            \n'
#                                      '            with col2:\n'
#                                      '                if st.button("📝 Download '
#                                      'as DOCX", type="secondary"):\n'
#                                      '                    try:\n'
#                                      '                        docx_buffer = '
#                                      'doc_funcs.generate_docx_document(\n'
#                                      '                            '
#                                      'st.session_state.documentation,\n'
#                                      '                            '
#                                      'st.session_state.repo_info\n'
#                                      '                        )\n'
#                                      '                        \n'
#                                      '                        '
#                                      'st.download_button(\n'
#                                      '                            label="💾 '
#                                      'Download DOCX",\n'
#                                      '                            '
#                                      'data=docx_buffer.getvalue(),\n'
#                                      '                            '
#                                      'file_name=f"{st.session_state.repo_info[\'name\']}_architecture.docx",\n'
#                                      '                            '
#                                      'mime="application/vnd.openxmlformats-officedocument.wordprocessingml.document"\n'
#                                      '                        )\n'
#                                      '                        \n'
#                                      '                    except Exception as '
#                                      'e:\n'
#                                      '                        st.error(f"Error '
#                                      'generating DOCX: {str(e)}")\n'
#                                      '\n'
#                                      'if __name__ == "__main__":\n'
#                                      '    main()\n',
#                           'size': 10368,
#                           'type': '.py'},
#                'document_generator_functions.py': {'content': 'import io\n'
#                                                               'from typing '
#                                                               'import Dict, '
#                                                               'Any\n'
#                                                               'from docx '
#                                                               'import '
#                                                               'Document\n'
#                                                               'from '
#                                                               'docx.shared '
#                                                               'import Inches\n'
#                                                               'from '
#                                                               'docx.enum.text '
#                                                               'import '
#                                                               'WD_ALIGN_PARAGRAPH\n'
#                                                               'from '
#                                                               'reportlab.lib.pagesizes '
#                                                               'import letter, '
#                                                               'A4\n'
#                                                               'from '
#                                                               'reportlab.lib.styles '
#                                                               'import '
#                                                               'getSampleStyleSheet, '
#                                                               'ParagraphStyle\n'
#                                                               'from '
#                                                               'reportlab.lib.units '
#                                                               'import inch\n'
#                                                               'from '
#                                                               'reportlab.platypus '
#                                                               'import '
#                                                               'SimpleDocTemplate, '
#                                                               'Paragraph, '
#                                                               'Spacer, Table, '
#                                                               'TableStyle\n'
#                                                               'from '
#                                                               'reportlab.lib '
#                                                               'import colors\n'
#                                                               'from '
#                                                               'reportlab.lib.enums '
#                                                               'import '
#                                                               'TA_CENTER, '
#                                                               'TA_LEFT\n'
#                                                               'from datetime '
#                                                               'import '
#                                                               'datetime\n'
#                                                               'import logging\n'
#                                                               '\n'
#                                                               'def '
#                                                               'setup_pdf_styles():\n'
#                                                               '    """Setup '
#                                                               'custom styles '
#                                                               'for PDF '
#                                                               'generation."""\n'
#                                                               '    styles = '
#                                                               'getSampleStyleSheet()\n'
#                                                               '    \n'
#                                                               '    # Title '
#                                                               'style\n'
#                                                               '    '
#                                                               'styles.add(ParagraphStyle(\n'
#                                                               '        '
#                                                               "name='CustomTitle',\n"
#                                                               '        '
#                                                               "parent=styles['Title'],\n"
#                                                               '        '
#                                                               'fontSize=24,\n'
#                                                               '        '
#                                                               'spaceAfter=30,\n'
#                                                               '        '
#                                                               'alignment=TA_CENTER,\n'
#                                                               '        '
#                                                               "textColor=colors.HexColor('#2E8B57')\n"
#                                                               '    ))\n'
#                                                               '    \n'
#                                                               '    # Heading '
#                                                               'styles\n'
#                                                               '    '
#                                                               'styles.add(ParagraphStyle(\n'
#                                                               '        '
#                                                               "name='CustomHeading1',\n"
#                                                               '        '
#                                                               "parent=styles['Heading1'],\n"
#                                                               '        '
#                                                               'fontSize=18,\n'
#                                                               '        '
#                                                               'spaceAfter=12,\n'
#                                                               '        '
#                                                               'spaceBefore=20,\n'
#                                                               '        '
#                                                               "textColor=colors.HexColor('#2E8B57')\n"
#                                                               '    ))\n'
#                                                               '    \n'
#                                                               '    '
#                                                               'styles.add(ParagraphStyle(\n'
#                                                               '        '
#                                                               "name='CustomHeading2',\n"
#                                                               '        '
#                                                               "parent=styles['Heading2'],\n"
#                                                               '        '
#                                                               'fontSize=14,\n'
#                                                               '        '
#                                                               'spaceAfter=10,\n'
#                                                               '        '
#                                                               'spaceBefore=15,\n'
#                                                               '        '
#                                                               "textColor=colors.HexColor('#4682B4')\n"
#                                                               '    ))\n'
#                                                               '    \n'
#                                                               '    # Code '
#                                                               'style\n'
#                                                               '    '
#                                                               'styles.add(ParagraphStyle(\n'
#                                                               '        '
#                                                               "name='CodeStyle',\n"
#                                                               '        '
#                                                               "parent=styles['Code'],\n"
#                                                               '        '
#                                                               'fontSize=10,\n'
#                                                               '        '
#                                                               "fontName='Courier',\n"
#                                                               '        '
#                                                               "backgroundColor=colors.HexColor('#F5F5F5'),\n"
#                                                               '        '
#                                                               'leftIndent=20,\n'
#                                                               '        '
#                                                               'rightIndent=20,\n'
#                                                               '        '
#                                                               'spaceAfter=10\n'
#                                                               '    ))\n'
#                                                               '    \n'
#                                                               '    return '
#                                                               'styles\n'
#                                                               '\n'
#                                                               'def '
#                                                               'generate_pdf_document(documentation: '
#                                                               'Dict[str, Any], '
#                                                               'repo_info: '
#                                                               'Dict[str, str]) '
#                                                               '-> io.BytesIO:\n'
#                                                               '    """Generate '
#                                                               'PDF '
#                                                               'documentation."""\n'
#                                                               '    try:\n'
#                                                               '        buffer '
#                                                               '= io.BytesIO()\n'
#                                                               '        doc = '
#                                                               'SimpleDocTemplate(\n'
#                                                               '            '
#                                                               'buffer,\n'
#                                                               '            '
#                                                               'pagesize=A4,\n'
#                                                               '            '
#                                                               'rightMargin=72,\n'
#                                                               '            '
#                                                               'leftMargin=72,\n'
#                                                               '            '
#                                                               'topMargin=72,\n'
#                                                               '            '
#                                                               'bottomMargin=18\n'
#                                                               '        )\n'
#                                                               '        \n'
#                                                               '        styles '
#                                                               '= '
#                                                               'setup_pdf_styles()\n'
#                                                               '        \n'
#                                                               '        # Build '
#                                                               'document '
#                                                               'content\n'
#                                                               '        story = '
#                                                               '[]\n'
#                                                               '        \n'
#                                                               '        # Title '
#                                                               'page\n'
#                                                               '        '
#                                                               'story.append(Paragraph(f"Architecture '
#                                                               'Documentation", '
#                                                               "styles['CustomTitle']))\n"
#                                                               '        '
#                                                               'story.append(Spacer(1, '
#                                                               '20))\n'
#                                                               '        '
#                                                               'story.append(Paragraph(f"Repository: '
#                                                               '{repo_info[\'full_name\']}", '
#                                                               "styles['Heading2']))\n"
#                                                               '        '
#                                                               'story.append(Paragraph(f"Description: '
#                                                               '{repo_info[\'description\']}", '
#                                                               "styles['Normal']))\n"
#                                                               '        '
#                                                               'story.append(Spacer(1, '
#                                                               '10))\n'
#                                                               '        '
#                                                               'story.append(Paragraph(f"Generated '
#                                                               'on: '
#                                                               "{datetime.now().strftime('%B "
#                                                               '%d, %Y\')}", '
#                                                               "styles['Normal']))\n"
#                                                               '        '
#                                                               'story.append(Spacer(1, '
#                                                               '30))\n'
#                                                               '        \n'
#                                                               '        # '
#                                                               'Repository '
#                                                               'statistics\n'
#                                                               '        if '
#                                                               "'key_statistics' "
#                                                               'in '
#                                                               'documentation:\n'
#                                                               '            '
#                                                               'stats = '
#                                                               "documentation['key_statistics']\n"
#                                                               '            '
#                                                               'story.append(Paragraph("Repository '
#                                                               'Statistics", '
#                                                               "styles['CustomHeading1']))\n"
#                                                               '            \n'
#                                                               '            '
#                                                               'stats_data = [\n'
#                                                               '                '
#                                                               "['Metric', "
#                                                               "'Value'],\n"
#                                                               '                '
#                                                               "['Total Files', "
#                                                               "str(stats.get('total_files', "
#                                                               "'N/A'))],\n"
#                                                               '                '
#                                                               "['Code Files', "
#                                                               "str(stats.get('code_files', "
#                                                               "'N/A'))],\n"
#                                                               '                '
#                                                               "['Analyzed "
#                                                               "Files', "
#                                                               "str(stats.get('analyzed_files', "
# ...
#                                        'a valid GitHub repository URL."""\n'
#                                        '    if not url:\n'
#                                        '        return False\n'
#                                        '    \n'
#                                        '    try:\n'
#                                        '        parsed = urlparse(url)\n'
#                                        '        if parsed.netloc != '
#                                        "'github.com':\n"
#                                        '            return False\n'
#                                        '        \n'
#                                        '        # Check if path matches GitHub '
#                                        'repo pattern\n'
#                                        '        path_parts = '
#                                        "parsed.path.strip('/').split('/')\n"
#                                        '        if len(path_parts) != 2:\n'
#                                        '            return False\n'
#                                        '        \n'
#                                        '        # Check for valid owner and '
#                                        'repo names\n'
#                                        '        owner, repo = path_parts\n'
#                                        '        if not owner or not repo:\n'
#                                        '            return False\n'
#                                        '        \n'
#                                        '        # Remove .git suffix if '
#                                        'present\n'
#                                        "        if repo.endswith('.git'):\n"
#                                        '            repo = repo[:-4]\n'
#                                        '        \n'
#                                        '        # Basic validation for GitHub '
#                                        'username/repo naming rules\n'
#                                        '        pattern = '
#                                        "r'^[a-zA-Z0-9\\-_.]+$'\n"
#                                        '        if not re.match(pattern, '
#                                        'owner) or not re.match(pattern, '
#                                        'repo):\n'
#                                        '            return False\n'
#                                        '        \n'
#                                        '        return True\n'
#                                        '        \n'
#                                        '    except Exception as e:\n'
#                                        '        logging.error(f"Error '
#                                        'validating GitHub URL: {e}")\n'
#                                        '        return False\n'
#                                        '\n'
#                                        'def extract_repo_info(url: str) -> '
#                                        'Optional[Dict[str, str]]:\n'
#                                        '    """Extract owner and repository '
#                                        'name from GitHub URL."""\n'
#                                        '    if not validate_github_url(url):\n'
#                                        '        return None\n'
#                                        '    \n'
#                                        '    try:\n'
#                                        '        parsed = urlparse(url)\n'
#                                        '        path_parts = '
#                                        "parsed.path.strip('/').split('/')\n"
#                                        '        owner, repo = path_parts\n'
#                                        '        \n'
#                                        '        # Remove .git suffix if '
#                                        'present\n'
#                                        "        if repo.endswith('.git'):\n"
#                                        '            repo = repo[:-4]\n'
#                                        '        \n'
#                                        '        return {\n'
#                                        "            'owner': owner,\n"
#                                        "            'repo': repo,\n"
#                                        "            'full_name': "
#                                        'f"{owner}/{repo}"\n'
#                                        '        }\n'
#                                        '        \n'
#                                        '    except Exception as e:\n'
#                                        '        logging.error(f"Error '
#                                        'extracting repo info: {e}")\n'
#                                        '        return None\n'
#                                        '\n'
#                                        'def format_file_size(size_bytes: int) '
#                                        '-> str:\n'
#                                        '    """Format file size in human '
#                                        'readable format."""\n'
#                                        '    if size_bytes == 0:\n'
#                                        '        return "0 B"\n'
#                                        '    \n'
#                                        '    size_names = ["B", "KB", "MB", '
#                                        '"GB"]\n'
#                                        '    i = 0\n'
#                                        '    while size_bytes >= 1024 and i < '
#                                        'len(size_names) - 1:\n'
#                                        '        size_bytes = int(size_bytes / '
#                                        '1024.0)\n'
#                                        '        i += 1\n'
#                                        '    \n'
#                                        '    return f"{size_bytes:.1f} '
#                                        '{size_names[i]}"\n'
#                                        '\n'
#                                        'def truncate_text(text: str, '
#                                        'max_length: int = 100) -> str:\n'
#                                        '    """Truncate text to specified '
#                                        'length with ellipsis."""\n'
#                                        '    if len(text) <= max_length:\n'
#                                        '        return text\n'
#                                        '    return text[:max_length - 3] + '
#                                        '"..."\n'
#                                        '\n'
#                                        'def sanitize_filename(filename: str) '
#                                        '-> str:\n'
#                                        '    """Sanitize filename for safe file '
#                                        'system usage."""\n'
#                                        '    # Remove or replace invalid '
#                                        'characters\n'
#                                        '    invalid_chars = \'<>:"/\\\\|?*\'\n'
#                                        '    for char in invalid_chars:\n'
#                                        '        filename = '
#                                        "filename.replace(char, '_')\n"
#                                        '    \n'
#                                        '    # Remove leading/trailing spaces '
#                                        'and dots\n'
#                                        "    filename = filename.strip(' .')\n"
#                                        '    \n'
#                                        '    # Ensure filename is not empty\n'
#                                        '    if not filename:\n'
#                                        '        filename = "untitled"\n'
#                                        '    \n'
#                                        '    return filename\n'
#                                        '\n'
#                                        'def parse_mermaid_diagram(text: str) '
#                                        '-> Optional[str]:\n'
#                                        '    """Extract Mermaid diagram code '
#                                        'from text."""\n'
#                                        '    try:\n'
#                                        '        # Look for mermaid code '
#                                        'blocks\n'
#                                        '        patterns = [\n'
#                                        '            '
#                                        "r'```mermaid\\s*\\n(.*?)\\n```',\n"
#                                        '            '
#                                        "r'```\\s*\\n(graph\\s+.*?)\\n```',\n"
#                                        '            '
#                                        "r'```\\s*\\n(flowchart\\s+.*?)\\n```'\n"
#                                        '        ]\n'
#                                        '        \n'
#                                        '        for pattern in patterns:\n'
#                                        '            match = re.search(pattern, '
#                                        'text, re.DOTALL | re.IGNORECASE)\n'
#                                        '            if match:\n'
#                                        '                return '
#                                        'match.group(1).strip()\n'
#                                        '        \n'
#                                        '        return None\n'
#                                        '        \n'
#                                        '    except Exception as e:\n'
#                                        '        logging.error(f"Error parsing '
#                                        'Mermaid diagram: {e}")\n'
#                                        '        return None\n'
#                                        '\n'
#                                        'def create_modules_table(modules_text: '
#                                        'str) -> List[Dict[str, str]]:\n'
#                                        '    """Parse modules text and create '
#                                        'structured table data."""\n'
#                                        '    try:\n'
#                                        '        modules = []\n'
#                                        '        \n'
#                                        '        # Try to parse structured '
#                                        'module information\n'
#                                        '        lines = '
#                                        "modules_text.split('\\n')\n"
#                                        '        current_module = {}\n'
#                                        '        \n'
#                                        '        for line in lines:\n'
#                                        '            line = line.strip()\n'
#                                        '            \n'
#                                        '            # Look for module headers '
#                                        'or bullet points\n'
#                                        "            if line.startswith('- ') "
#                                        "or line.startswith('* '):\n"
#                                        '                if current_module:\n'
#                                        '                    '
#                                        'modules.append(current_module)\n'
#                                        '                    current_module = '
#                                        '{}\n'
#                                        '                \n'
#                                        '                # Extract module name\n'
#                                        '                module_name = '
#                                        "line[2:].split(':')[0].strip()\n"
#                                        "                current_module['name'] "
#                                        '= module_name\n'
#                                        '                \n'
#                                        '                # Extract purpose if '
#                                        'available\n'
#                                        "                if ':' in line:\n"
#                                        '                    purpose = '
#                                        "':'.join(line.split(':')[1:]).strip()\n"
#                                        '                    '
#                                        "current_module['purpose'] = purpose\n"
#                                        '                else:\n'
#                                        '                    '
#                                        "current_module['purpose'] = ''\n"
#                                        '                \n'
#                                        '                '
#                                        "current_module['files'] = ''\n"
#                                        '                '
#                                        "current_module['dependencies'] = ''\n"
#                                        '            \n'
#                                        '            elif line and '
#                                        'current_module:\n'
#                                        '                # Add additional '
#                                        'information to current module\n'
#                                        "                if 'files' not in "
#                                        'current_module or not '
#                                        "current_module['files']:\n"
#                                        '                    '
#                                        "current_module['files'] = line\n"
#                                        "                elif 'dependencies' "
#                                        'not in current_module or not '
#                                        "current_module['dependencies']:\n"
#                                        '                    '
#                                        "current_module['dependencies'] = line\n"
#                                        '        \n'
#                                        '        # Add last module\n'
#                                        '        if current_module:\n'
#                                        '            '
#                                        'modules.append(current_module)\n'
#                                        '        \n'
#                                        '        return modules\n'
#                                        '        \n'
#                                        '    except Exception as e:\n'
#                                        '        logging.error(f"Error creating '
#                                        'modules table: {e}")\n'
#                                        '        return []\n'
#                                        '\n'
#                                        'def setup_logging():\n'
#                                        '    """Setup logging '
#                                        'configuration."""\n'
#                                        '    logging.basicConfig(\n'
#                                        '        level=logging.INFO,\n'
#                                        "        format='%(asctime)s - %(name)s "
#                                        "- %(levelname)s - %(message)s',\n"
#                                        '        handlers=[\n'
#                                        '            logging.StreamHandler()\n'
#                                        '        ]\n'
#                                        '    )\n',
#                             'size': 5622,
#                             'type': '.py'}},
#  'statistics': {'analyzed_files': 7,
#                 'code_files': 7,
#                 'languages': {'.md': 1, '.py': 4, '.toml': 1, '.txt': 1},
#                 'skipped_files': 1,
#                 'total_files': 7}}
